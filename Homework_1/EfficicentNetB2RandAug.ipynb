# %% [markdown]
# # 0 - IMPORT LIBRARIES

# %%
import keras_cv as kcv
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
from tensorflow.keras.models import Sequential

import os
import math
import random
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
# Random seed for reproducibility
seed = 0
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %% [markdown]
# # 1 - LOAD & AUGMENT DATA

# %%
X =  np.load('/kaggle/input/dataset-bal/X.npy')
y =  np.load('/kaggle/input/dataset-bal/y.npy')

print(X.shape)
print(y.shape)
# Out:
# (18640, 96, 96, 3)
# (18640, 1)

# %%
#2 - SPLIT DATA
split_par = 0.2

X_train, X_test_val, y_train, y_test_val = train_test_split(X, 
                                                            y,
                                                            random_state=seed,
                                                            test_size = split_par,
                                                            stratify=np.argmax(y,axis=1))

X_test, X_val, y_test, y_val = train_test_split(X_test_val, 
                                                y_test_val, 
                                                random_state=seed, 
                                                test_size = 0.5, 
                                                stratify=np.argmax(y_test_val,axis=1))

y_train = tfk.utils.to_categorical(y_train)
y_test = tfk.utils.to_categorical(y_test)
y_val = tfk.utils.to_categorical(y_val)

# %%
#Apply augmentation
randaug=kcv.layers.RandAugment(value_range=(0,255),seed=seed)
X_train = randaug(X_train)

# %%
#Plot first num images to see the augmentations applied
num = 100

fig = plt.figure(figsize=(10,10))
for i in range(1, num+1):
    fig.add_subplot(10, 10, i)
    plt.imshow(X_train[i]/255)
plt.show()

# %% [markdown]
# # 2 - BUILD MODEL

# %%
# Initialise EfficientNetB2 model with imagent problem weights

effnetV2S = tfk.applications.EfficientNetB2(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=(96, 96, 3),
    pooling='avg',
    classes=8,
    classifier_activation=None,
)

effnetV2S.trainable = False

#Define given inputs
inputs = tfk.Input(shape=(96, 96, 3), name='input_layer')

#Create sequantial layers to apply little geometric augmentations to the inputs
augmentation = tf.keras.Sequential([
    tfkl.RandomFlip("horizontal", seed = seed),
    tfkl.RandomTranslation(0.2, 0.2)
], name='preprocessing')

x = augmentation(inputs)
x = effnetV2S(x)

#Squeeze-and-Excitation Attention (similar to SE block)
se = tfkl.Dense(x.shape[-1] // 4, activation='relu')(x)  # Squeeze step
se = tfkl.Dense(x.shape[-1], activation='sigmoid')(se)  # Excitation step
x = tfkl.Multiply()([x, se])  # Scale feature maps by learned importance weights

# Add Dense, Dropout and Batch Normalization layers
x = tfkl.Dense(128, activation='relu', name='dense_1')(x)
x = tfkl.BatchNormalization(name='batch_norm_1')(x)
x = tfkl.Dropout(0.4, name='dropout_1')(x)

x = tfkl.Dropout(0.2, name='dropout_2')(x)

#Define last layer
outputs = tfkl.Dense(y_train.shape[-1], activation='softmax', name='dense2')(x)

#Create complete model and compile it
tl_model = tfk.Model(inputs=inputs, outputs=outputs, name='model')
tl_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(2e-4), metrics=['accuracy','F1Score'])

# Display a summary of the model architecture
tl_model.summary(expand_nested=False)
# Out:
# Model: "model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 96, 96, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ preprocessing       │ (None, 96, 96, 3) │          0 │ input_layer[0][0] │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ efficientnetb2      │ (None, 1408)      │  7,768,569 │ preprocessing[0]… │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 352)       │    495,968 │ efficientnetb2[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 1408)      │    497,024 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 1408)      │          0 │ efficientnetb2[0… │
# │ (Multiply)          │                   │            │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │    180,352 │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_norm_1        │ (None, 128)       │        512 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ batch_norm_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 128)       │          0 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense2 (Dense)      │ (None, 8)         │      1,032 │ dropout_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,943,457 (34.12 MB)
#  Trainable params: 1,174,632 (4.48 MB)
#  Non-trainable params: 7,768,825 (29.64 MB)

# %% [markdown]
# # 3 - TRANSFER LEARNING

# %%
# Train the model
tl_history = tl_model.fit(
    x=X_train,
    y=y_train,
    batch_size=64,
    epochs=40,
    validation_data=(X_val, y_val),
    callbacks=[tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=5, restore_best_weights=True)]
).history

# Calculate and print the best validation accuracy achieved
final_val_accuracy = round(max(tl_history['val_accuracy']) * 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file
model_filename = 'Model_pre.keras'
tl_model.save(model_filename)

del tl_model
# Out:
# Epoch 1/40
# 2024-11-24 22:25:20.789526: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/model_1/efficientnetb2_1/block1b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 32s 77ms/step - F1Score: 0.2683 - accuracy: 0.2701 - loss: 2.3554 - val_F1Score: 0.6083 - val_accuracy: 0.6078 - val_loss: 1.2852
# Epoch 2/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - F1Score: 0.4396 - accuracy: 0.4416 - loss: 1.5974 - val_F1Score: 0.6800 - val_accuracy: 0.6781 - val_loss: 0.9080
# Epoch 3/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.4922 - accuracy: 0.4951 - loss: 1.4300 - val_F1Score: 0.6889 - val_accuracy: 0.6878 - val_loss: 0.8854
# Epoch 4/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.5278 - accuracy: 0.5303 - loss: 1.3365 - val_F1Score: 0.7167 - val_accuracy: 0.7146 - val_loss: 0.8171
# Epoch 5/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.5502 - accuracy: 0.5522 - loss: 1.2537 - val_F1Score: 0.7256 - val_accuracy: 0.7242 - val_loss: 0.7738
# Epoch 6/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.5688 - accuracy: 0.5705 - loss: 1.1983 - val_F1Score: 0.7433 - val_accuracy: 0.7414 - val_loss: 0.7538
# Epoch 7/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.5840 - accuracy: 0.5859 - loss: 1.1642 - val_F1Score: 0.7392 - val_accuracy: 0.7355 - val_loss: 0.7602
# Epoch 8/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.5995 - accuracy: 0.6014 - loss: 1.1188 - val_F1Score: 0.7690 - val_accuracy: 0.7672 - val_loss: 0.6715
# Epoch 9/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.5939 - accuracy: 0.5953 - loss: 1.1217 - val_F1Score: 0.7713 - val_accuracy: 0.7661 - val_loss: 0.6767
# Epoch 10/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.6176 - accuracy: 0.6194 - loss: 1.0714 - val_F1Score: 0.7786 - val_accuracy: 0.7774 - val_loss: 0.6663
# Epoch 11/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.6186 - accuracy: 0.6200 - loss: 1.0578 - val_F1Score: 0.7870 - val_accuracy: 0.7859 - val_loss: 0.6298
# Epoch 12/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 52ms/step - F1Score: 0.6241 - accuracy: 0.6257 - loss: 1.0460 - val_F1Score: 0.7568 - val_accuracy: 0.7538 - val_loss: 0.7033
# Epoch 13/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.6265 - accuracy: 0.6279 - loss: 1.0477 - val_F1Score: 0.7870 - val_accuracy: 0.7849 - val_loss: 0.6139
# Epoch 14/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.6348 - accuracy: 0.6360 - loss: 1.0145 - val_F1Score: 0.8084 - val_accuracy: 0.8079 - val_loss: 0.5644
# Epoch 15/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.6415 - accuracy: 0.6428 - loss: 1.0055 - val_F1Score: 0.7931 - val_accuracy: 0.7913 - val_loss: 0.6084
# Epoch 16/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.6522 - accuracy: 0.6537 - loss: 0.9698 - val_F1Score: 0.7996 - val_accuracy: 0.7951 - val_loss: 0.5981
# Epoch 17/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.6493 - accuracy: 0.6501 - loss: 0.9791 - val_F1Score: 0.7937 - val_accuracy: 0.7935 - val_loss: 0.5923
# Epoch 18/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.6532 - accuracy: 0.6543 - loss: 0.9626 - val_F1Score: 0.7930 - val_accuracy: 0.7908 - val_loss: 0.6092
# Epoch 19/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.6685 - accuracy: 0.6699 - loss: 0.9532 - val_F1Score: 0.8165 - val_accuracy: 0.8149 - val_loss: 0.5400
# Epoch 20/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 52ms/step - F1Score: 0.6630 - accuracy: 0.6640 - loss: 0.9362 - val_F1Score: 0.8184 - val_accuracy: 0.8144 - val_loss: 0.5558
# Epoch 21/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.6688 - accuracy: 0.6698 - loss: 0.9179 - val_F1Score: 0.8234 - val_accuracy: 0.8219 - val_loss: 0.5320
# Epoch 22/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.6773 - accuracy: 0.6784 - loss: 0.9103 - val_F1Score: 0.7871 - val_accuracy: 0.7838 - val_loss: 0.6165
# Epoch 23/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.6759 - accuracy: 0.6768 - loss: 0.9109 - val_F1Score: 0.8172 - val_accuracy: 0.8155 - val_loss: 0.5357
# Epoch 24/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.6780 - accuracy: 0.6790 - loss: 0.8938 - val_F1Score: 0.8313 - val_accuracy: 0.8299 - val_loss: 0.5168
# Epoch 25/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.6868 - accuracy: 0.6877 - loss: 0.8843 - val_F1Score: 0.8010 - val_accuracy: 0.7999 - val_loss: 0.5683
# Epoch 26/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.6879 - accuracy: 0.6891 - loss: 0.8722 - val_F1Score: 0.8190 - val_accuracy: 0.8176 - val_loss: 0.5139
# Epoch 27/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.6838 - accuracy: 0.6848 - loss: 0.8743 - val_F1Score: 0.8195 - val_accuracy: 0.8171 - val_loss: 0.5248
# Epoch 28/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.6905 - accuracy: 0.6913 - loss: 0.8601 - val_F1Score: 0.8256 - val_accuracy: 0.8246 - val_loss: 0.5048
# Epoch 29/40
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - F1Score: 0.6923 - accuracy: 0.6938 - loss: 0.8583 - val_F1Score: 0.8204 - val_accuracy: 0.8181 - val_loss: 0.5196
# Final validation accuracy: 82.99%

# %% [markdown]
# # 4 - FINE TUNING

# %%
# Re-load the model after transfer learning
ft_model = tfk.models.load_model('Model_pre.keras')

# %%
# Set the effnetB2 model layers as trainable
ft_model.get_layer('efficientnetb2').trainable = True

# Set all effnetB2 layers as non-trainable
for layer in ft_model.get_layer('efficientnetb2').layers:
    layer.trainable = False

# Enable training only for Conv2D and DepthwiseConv2D layers
for i, layer in enumerate(ft_model.get_layer('efficientnetb2').layers):
    if isinstance(layer, tf.keras.layers.Conv2D) or isinstance(layer, tf.keras.layers.DepthwiseConv2D):
        layer.trainable = True
        
# Set the number of layers to freeze
N = 100

# Set the first N layers as non-trainable
for i, layer in enumerate(ft_model.get_layer('efficientnetb2').layers[:N]):
    layer.trainable = False

# Compile the model
ft_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Lion(learning_rate=5e-5, weight_decay=1e-5), metrics=['accuracy','F1Score'])

# %%
# Fine-tune the model
ft_history = ft_model.fit(
    x = X_train,
    y = y_train,
    batch_size = 64,
    epochs = 100,
    validation_data = (X_val, y_val),
    callbacks = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=5, restore_best_weights=True)]
).history

# Calculate and print the final validation accuracy
final_val_accuracy = round(max(ft_history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file
model_filename = 'Model_post.keras'
ft_model.save(model_filename)
# Out:
# Epoch 1/100
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 44s 110ms/step - F1Score: 0.7327 - accuracy: 0.7333 - loss: 0.7649 - val_F1Score: 0.9507 - val_accuracy: 0.9506 - val_loss: 0.1426
# Epoch 2/100
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 22s 94ms/step - F1Score: 0.8716 - accuracy: 0.8718 - loss: 0.3953 - val_F1Score: 0.9583 - val_accuracy: 0.9587 - val_loss: 0.1198
# Epoch 3/100
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 22s 93ms/step - F1Score: 0.9073 - accuracy: 0.9076 - loss: 0.2850 - val_F1Score: 0.9717 - val_accuracy: 0.9721 - val_loss: 0.0952
# Epoch 4/100
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 22s 93ms/step - F1Score: 0.9278 - accuracy: 0.9278 - loss: 0.2304 - val_F1Score: 0.9724 - val_accuracy: 0.9726 - val_loss: 0.0984
# Epoch 5/100
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 22s 94ms/step - F1Score: 0.9341 - accuracy: 0.9342 - loss: 0.2078 - val_F1Score: 0.9767 - val_accuracy: 0.9769 - val_loss: 0.0789
# Epoch 6/100
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 22s 93ms/step - F1Score: 0.9387 - accuracy: 0.9386 - loss: 0.1855 - val_F1Score: 0.9664 - val_accuracy: 0.9667 - val_loss: 0.1071
# Epoch 7/100
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 22s 93ms/step - F1Score: 0.9461 - accuracy: 0.9460 - loss: 0.1618 - val_F1Score: 0.9747 - val_accuracy: 0.9748 - val_loss: 0.0851
# Epoch 8/100
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 22s 93ms/step - F1Score: 0.9521 - accuracy: 0.9520 - loss: 0.1478 - val_F1Score: 0.9838 - val_accuracy: 0.9839 - val_loss: 0.0562
# Epoch 9/100
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 22s 93ms/step - F1Score: 0.9585 - accuracy: 0.9585 - loss: 0.1339 - val_F1Score: 0.9739 - val_accuracy: 0.9742 - val_loss: 0.0875
# Epoch 10/100
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 22s 93ms/step - F1Score: 0.9587 - accuracy: 0.9588 - loss: 0.1335 - val_F1Score: 0.9770 - val_accuracy: 0.9769 - val_loss: 0.0724
# Epoch 11/100
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 22s 93ms/step - F1Score: 0.9581 - accuracy: 0.9582 - loss: 0.1291 - val_F1Score: 0.9706 - val_accuracy: 0.9710 - val_loss: 0.1171
# Epoch 12/100
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 22s 93ms/step - F1Score: 0.9654 - accuracy: 0.9653 - loss: 0.1084 - val_F1Score: 0.9717 - val_accuracy: 0.9721 - val_loss: 0.0929
# Epoch 13/100
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 22s 93ms/step - F1Score: 0.9663 - accuracy: 0.9664 - loss: 0.1046 - val_F1Score: 0.9749 - val_accuracy: 0.9748 - val_loss: 0.0735
# Final validation accuracy: 98.39%

# %% [markdown]
# # 5 - HISTORY PLOT

# %%
# Plot loss
fig = plt.figure()
plt.plot(ft_history['loss'], color='teal', label='loss')
plt.plot(ft_history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# Plot the training
plt.figure(figsize=(15,5))
plt.plot(ft_history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(ft_history['val_loss'], label='Vanilla CNN', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

#Plot accuracy
plt.figure(figsize=(15,5))
plt.plot(ft_history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(ft_history['val_accuracy'], label='Vanilla CNN', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %% [markdown]
# # 6 - EVAULATION ON TEST SET

# %%
pred = np.argmax(ft_model.predict(X_test), axis=1)
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step

# %%
true = np.argmax(y_test,axis=1)
cm = confusion_matrix(true, pred)
labels_cm = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Calculate accuracy
accuracy = accuracy_score(true, pred)
print(f"Accuracy on test data: {accuracy * 100:.2f}%")
# Calculate precision
precision = precision_score(true, pred, average='weighted')
print(f'Precision score over the test set: {round(precision, 4)}')

# Normalized confusion matrix by class
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
plt.figure(figsize=(8, 6))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='Blues', xticklabels=np.arange(8), yticklabels=np.arange(8))
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Normalized Confusion Matrix')
plt.show()
# Out:
# Accuracy on test data: 98.12%
# Precision score over the test set: 0.9813

# %% [markdown]
# # 7 - ZIP MODEL

# %%
# %%writefile model.py
import numpy as np

import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl

class Model:
    def __init__(self):
        self.neural_network = tfk.models.load_model('Model_post.keras')

    def predict(self, X):
        preds = self.neural_network.predict(X)
        if len(preds.shape) == 2:
            preds = np.argmax(preds, axis=1)
        return preds
# Out:
# Writing model.py

# %%
filename = f'efficientnet-b2_randaug'
# !zip {filename} model.py Model_post.keras
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
#   adding: model.py (deflated 49%)
#   adding: Model_post.keras (deflated 8%)
